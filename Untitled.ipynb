# %%
from sqlalchemy import create_engine

# %%
Engine = create_engine(f'postgresql://postgres:postgres@localhost:5432/postgres')

# %%
import pandas
def read_sql_to_df(query):
    return pandas.read_sql_query(query, con=Engine)
class ChannelTable:
    def __init__(self, stream, time=None):
        self.stream = stream
    
    @property
    def table_name(self):
        return 

    def streams_count(self):
        return read_sql_to_df(f'select DISTINCT started_at from {self.table_name};')


class StreamTable(ChannelTable):
    def __init__(self, stream, time=None):
        self.time = time
        super(StreamTable, self).__init__(stream)
    
    @property
    def condition(self):  
        return f"WHERE started_at = '{self.time}'" if self.time else ''

    @property
    def table_name(self):
        return self.stream

    def top_users_sql(self):
        query = f'SELECT username, COUNT(*) AS "count" from {self.table_name} {self.condition} group by username ORDER BY COUNT DESC;'
        print(query)
        return read_sql_to_df(query)
    
    def get_data_frame(self):
        query = f"SELECT * FROM {self.table_name} {self.condition}"
        return read_sql_to_df(query)
    
    def top_words(self, sort=False):
        sort = 'ORDER BY nentry DESC' if sort else ''
        query = f'SELECT word, nentry as "count" FROM ts_stat($$ \
                                SELECT to_tsvector({self.table_name}.msg) \
                                FROM {self.table_name} {self.condition}\
                                $$) {sort};'
        return read_sql_to_df(query)

# %%
i = StreamTable("sodapoppin")

# %%
i.streams_count()
# Out:
#              started_at
# 0  2020-03-04T19:52:16Z
# 1  2020-03-10T00:32:13Z
# 2  2020-03-07T19:50:57Z
# 3  2020-03-05T19:49:33Z
# 4  2020-03-03T19:03:14Z

# %%
i.top_users_sql()
# Out:
# SELECT username, COUNT(*) AS "count" from sodapoppin  group by username ORDER BY COUNT DESC;
#             username  count
# 0          guactoast   3205
# 1          kirisaite   3175
# 2             anaxai   3141
# 3               kalg   2461
# 4          bhshelley   1884
# ...              ...    ...
# 39897    manifresh38      1
# 39898      auron2ooo      1
# 39899  stacelsgaming      1
# 39900      vanhelsey      1
# 39901    keztherogue      1
#
# [39902 rows x 2 columns]

# %%
i.get_data_frame()
# Out:
#             id        username                                      msg  \
# 0            1     rosestride2             @vulpeshd hey widepeepoHappy
# 1            2     legoman0290                      the title PepeLaugh
# 2            3       wraykappa                                    pepeD
# 3            4        imtwista                      FINALLYYYY PogChamp
# 4            5        vulpeshd                        @rosestride2 hi 🙂
# ...        ...             ...                                      ...
# 453931  453922   sur3legend007                                       <3
# 453932  453923  igor_rezn1koff                               peepoLeave
# 453933  453924      zulmogarga                   not even 24 hours LULW
# 453934  453935     deraffenfan  @Jazzykat but i dont want to peepoLeave
# 453935  453936      the1_logan                    peepoLeave later chat
#
#                   started_at                  timestamp
# 0       2020-03-03T19:03:14Z 2020-03-03 19:04:46.715782
# 1       2020-03-03T19:03:14Z 2020-03-03 19:04:46.933259
# 2       2020-03-03T19:03:14Z 2020-03-03 19:04:51.617403
# 3       2020-03-03T19:03:14Z 2020-03-03 19:04:53.337675
# 4       2020-03-03T19:03:14Z 2020-03-03 19:04:53.774508
# ...                      ...                        ...
# 453931  2020-03-10T00:32:13Z 2020-03-10 23:42:20.845916
# 453932  2020-03-10T00:32:13Z 2020-03-10 23:42:21.058853
# 453933  2020-03-10T00:32:13Z 2020-03-10 23:42:21.944531
# 453934  2020-03-10T00:32:13Z 2020-03-10 23:42:30.212473
# 453935  2020-03-10T00:32:13Z 2020-03-10 23:42:30.292837
#
# [453936 rows x 5 columns]

# %%
i.time = "2020-03-04T19:52:16Z"

# %%
from collections import defaultdict
import re 
class PandasHandler:
    def __init__(self, data_frame):
        self.data_frame = data_frame

    def top_by_coulumn(self, column, top):
        return self.data_frame[column].value_counts().rename_axis(column).reset_index(name='count')[:top]
    
    def top_words_usage(self, column, top):
        result = defaultdict(int)
        for i in self.data_frame[column].to_dict().values():
            for word in re.findall(r"[a-zA-Z\-0-9\.:,_'\"]+", i):
                    result[word] += 1
        return pandas.DataFrame.from_dict(result, orient='index').sort_values(0, ascending=False)[:top].reset_index().rename(columns={0: 'count', 'index':"word"})
    
    def get_word_usage(self, word, column):
        return len(self.data_frame[column].str.lower().str.findall(r"[\b|^]*({})\b".format(word), flags = re.I).sum())

    def get_words_examples(self, word, column, char_limit=10):
        mask = (self.data_frame[column].str.len() >= char_limit )
        return self.data_frame[self.data_frame[column].str.contains(r"[\b|^]*({})\b".format(word), flags = re.I)].loc[mask]

# %%
ph = PandasHandler(i.get_data_frame())

# %%
ph.top_by_coulumn('username', 10)
# Out:
#        username  count
# 0          kalg   1112
# 1     kirisaite    615
# 2     guactoast    572
# 3        ludias    330
# 4      lidlfrog    302
# 5  forsenkkona_    282
# 6          zuby    279
# 7        anaxai    264
# 8     bhshelley    244
# 9   copsycallum    232

# %%
i.top_users_sql()[:10]
# Out:
# SELECT username, COUNT(*) AS "count" from sodapoppin WHERE started_at = '2020-03-04T19:52:16Z' group by username ORDER BY COUNT DESC;
#        username  count
# 0          kalg   1112
# 1     kirisaite    615
# 2     guactoast    572
# 3        ludias    330
# 4      lidlfrog    302
# 5  forsenkkona_    282
# 6          zuby    279
# 7        anaxai    264
# 8     bhshelley    244
# 9   copsycallum    232

# %%
word_isage = ph.top_words_usage('msg', 10)

# %%
ph.get_word_usage('yep cock', 'msg')
# Out:
# 13

# %%
ph.get_words_examples('YEP COCK', 'msg')
# Out:
# /home/randie/.local/lib/python3.6/site-packages/pandas/core/strings.py:1952: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#         id  username                                                msg  \
# 430  76657  copthatl  Yep COCK squadR Yep COCK squadR Yep COCK squad...
# 641  76868  copthatl    Yep COCK squadR Yep COCK squadR Yep COCK squadR
#
#                started_at                  timestamp
# 430  2020-03-04T19:52:16Z 2020-03-04 20:01:51.458789
# 641  2020-03-04T19:52:16Z 2020-03-04 20:03:01.116974

# %%
class ChannelTable:
    def __init__(self, stream, time=None):
        self.stream = stream
    
    @property
    def table_name(self):
        return 

    def streams_count(self):
        return read_sql_to_df(f'select DISTINCT started_at from {self.table_name};')

# %%
class TopTable(ChannelTable):
    top_kind = {
            'Words': 'word_usage',
            'Users': 'user_usage'
        }
    def __init__(self, stream, top_kind='Words', top_df=None):
        self.top_df = {}
        self.tkind = top_kind
        super(TopTable, self).__init__(stream)

    def read_tops(self):
        result = {}
        for k, v in self.top_kind.items():
            result[k] = read_sql_to_df(f'select * from {self.stream}{v} ORDER BY started_at;')
        return result 

    @property
    def table_name(self):
        return self.stream + self.top_kind[self.tkind]

    def write_df_to_sql(self, additional_value=None):
        for mode, df in self.top_df.items():
            if additional_value:
                (k,v), = additional_value.items()
                df[k] = v #datetime.strptime(v, '%Y-%m-%dT%XZ').date().isoformat()
            print(df.__class__)
            print(df)
            df.to_sql(self.stream + self.top_kind[mode], Engine,  if_exists="append")

# %%
tt = TopTable('sodapoppin', 'w', word_isage)

# %%
tt.table_name
# Out:
# 'sodapoppinword_usage'

# %%
tt.write_df_to_sql({'started_at':'2020-03-07T19:50:57Z'})

# %%
tt.streams_count()
# Out:
#              started_at
# 0  2020-03-07T19:50:57Z

# %%
st = StreamTable('sodapoppin')
tt =  TopTable('sodapoppin', 'w')

# %%
set(st.streams_count()['started_at'].to_list()) - set(tt.streams_count()['started_at'].to_list())
# Out:
# {'2020-03-03T19:03:14Z',
#  '2020-03-04T19:52:16Z',
#  '2020-03-05T19:49:33Z',
#  '2020-03-10T00:32:13Z'}

# %%
st.streams_count().merge(tt.streams_count(), on='started_at', how='left')
# Out:
#              started_at
# 0  2020-03-04T19:52:16Z
# 1  2020-03-10T00:32:13Z
# 2  2020-03-07T19:50:57Z
# 3  2020-03-05T19:49:33Z
# 4  2020-03-03T19:03:14Z

# %%
for j in pandas.concat([st.streams_count(), tt.streams_count()]).drop_duplicates(keep=False).values: 
    print(j[0])
    st.time = j[0]
    ph = PandasHandler(st.get_data_frame())
    tt.tkind = 'w'
    tt.top_df = ph.top_words_usage('msg', 10)
    print("done")
    tt.write_df_to_sql({'started_at': st.time})
    
    
    tt.tkind = 'u'
    tt.top_df = st.top_users_sql()[:10]
    print(tt.top_df)
    tt.write_df_to_sql({'started_at': st.time})
#    print(st.top_words(True)[:10])
# Out:
# 2020-03-04T19:52:16Z
# done
# SELECT username, COUNT(*) AS "count" from sodapoppin WHERE started_at = '2020-03-04T19:52:16Z' group by username ORDER BY COUNT DESC;
#        username  count
# 0          kalg   1112
# 1     kirisaite    615
# 2     guactoast    572
# 3        ludias    330
# 4      lidlfrog    302
# 5  forsenkkona_    282
# 6          zuby    279
# 7        anaxai    264
# 8     bhshelley    244
# 9   copsycallum    232
# 2020-03-10T00:32:13Z
# done
# SELECT username, COUNT(*) AS "count" from sodapoppin WHERE started_at = '2020-03-10T00:32:13Z' group by username ORDER BY COUNT DESC;
#        username  count
# 0     kirisaite   1651
# 1        anaxai   1439
# 2       mr_ragr   1376
# 3   theraeldeal   1202
# 4      jazzykat   1051
# 5     guactoast   1029
# 6         vissx    902
# 7        faiith    852
# 8      vulpeshd    795
# 9  cptmorgan132    792
# 2020-03-05T19:49:33Z
# done
# SELECT username, COUNT(*) AS "count" from sodapoppin WHERE started_at = '2020-03-05T19:49:33Z' group by username ORDER BY COUNT DESC;
#     username  count
# 0       kalg    455
# 1  guactoast    442
# 2     anaxai    349
# 3     ajeen_    318
# 4    norkore    302
# 5     ludias    273
# 6     fenrii    248
# 7  yuyuyuna_    248
# 8  kirisaite    233
# 9    szary94    219
# 2020-03-03T19:03:14Z
# done
# SELECT username, COUNT(*) AS "count" from sodapoppin WHERE started_at = '2020-03-03T19:03:14Z' group by username ORDER BY COUNT DESC;
#        username  count
# 0     kirisaite    676
# 1        ludias    522
# 2        anaxai    519
# 3     guactoast    480
# 4  basictuesday    480
# 5     victorjsz    420
# 6       sador90    369
# 7      vissione    360
# 8          zuby    277
# 9   smellygoatz    255

# %%
class Worker:
    def __init__(self, stream):
        self.stream_t = StreamTable(stream)
        self.top_t = TopTable(stream)

    def get_subset(self):
        try:  
            result =  pandas.concat([self.stream_t.streams_count(), self.top_t.streams_count()]).drop_duplicates(keep=False)
        except Exception:
            result =  self.stream_t.streams_count()
        return result
        
    def _set_top_attr(self, tkind, top_df):
        self.top_t.tkind, self.top_t.top_df[tkind] = (tkind, top_df)

    def _get_data_frame(self, time):
        self.stream_t.time = time
        return PandasHandler(self.stream_t.get_data_frame())

    def main(self):
        for j in self.get_subset().values: 
            print(j[0])
            self._set_top_attr('w', self._get_data_frame(j[0]).top_words_usage('msg', 10))
            self._set_top_attr('u', self.stream_t.top_users_sql()[:10])
            self.top_t.write_df_to_sql({'started_at': self.stream_t.time})

# %%
w = Worker('sodapoppin')

# %%
w.main()
# Out:
# 2020-03-04T19:52:16Z
# SELECT username, COUNT(*) AS "count" from sodapoppin WHERE started_at = '2020-03-04T19:52:16Z' group by username ORDER BY COUNT DESC;
# <class 'pandas.core.frame.DataFrame'>
#           word  count            started_at
# 0         LULW   3245  2020-03-04T19:52:16Z
# 1          the   2588  2020-03-04T19:52:16Z
# 2          Pog   2362  2020-03-04T19:52:16Z
# 3       monkaW   2331  2020-03-04T19:52:16Z
# 4  FeelsDabMan   2329  2020-03-04T19:52:16Z
# 5            a   1747  2020-03-04T19:52:16Z
# 6     OMEGALUL   1732  2020-03-04T19:52:16Z
# 7          you   1655  2020-03-04T19:52:16Z
# 8           is   1608  2020-03-04T19:52:16Z
# 9           to   1213  2020-03-04T19:52:16Z
# <class 'pandas.core.frame.DataFrame'>
#        username  count            started_at
# 0          kalg   1112  2020-03-04T19:52:16Z
# 1     kirisaite    615  2020-03-04T19:52:16Z
# 2     guactoast    572  2020-03-04T19:52:16Z
# 3        ludias    330  2020-03-04T19:52:16Z
# 4      lidlfrog    302  2020-03-04T19:52:16Z
# 5  forsenkkona_    282  2020-03-04T19:52:16Z
# 6          zuby    279  2020-03-04T19:52:16Z
# 7        anaxai    264  2020-03-04T19:52:16Z
# 8     bhshelley    244  2020-03-04T19:52:16Z
# 9   copsycallum    232  2020-03-04T19:52:16Z
# 2020-03-10T00:32:13Z
# SELECT username, COUNT(*) AS "count" from sodapoppin WHERE started_at = '2020-03-10T00:32:13Z' group by username ORDER BY COUNT DESC;
# <class 'pandas.core.frame.DataFrame'>
#         word  count            started_at
# 0       LULW  13229  2020-03-10T00:32:13Z
# 1        Pog  10888  2020-03-10T00:32:13Z
# 2        the   9035  2020-03-10T00:32:13Z
# 3        LUL   8036  2020-03-10T00:32:13Z
# 4     monkaW   7418  2020-03-10T00:32:13Z
# 5        you   7327  2020-03-10T00:32:13Z
# 6  PepeLaugh   6150  2020-03-10T00:32:13Z
# 7         is   5735  2020-03-10T00:32:13Z
# 8          a   5686  2020-03-10T00:32:13Z
# 9         to   4683  2020-03-10T00:32:13Z
# <class 'pandas.core.frame.DataFrame'>
#        username  count            started_at
# 0     kirisaite   1651  2020-03-10T00:32:13Z
# 1        anaxai   1439  2020-03-10T00:32:13Z
# 2       mr_ragr   1376  2020-03-10T00:32:13Z
# 3   theraeldeal   1202  2020-03-10T00:32:13Z
# 4      jazzykat   1051  2020-03-10T00:32:13Z
# 5     guactoast   1029  2020-03-10T00:32:13Z
# 6         vissx    902  2020-03-10T00:32:13Z
# 7        faiith    852  2020-03-10T00:32:13Z
# 8      vulpeshd    795  2020-03-10T00:32:13Z
# 9  cptmorgan132    792  2020-03-10T00:32:13Z
# 2020-03-07T19:50:57Z
# SELECT username, COUNT(*) AS "count" from sodapoppin WHERE started_at = '2020-03
# <class 'pandas.core.frame.DataFrame'>
#     username  count            started_at
# 0       kalg    455  2020-03-05T19:49:33Z
# 1  guactoast    442  2020-03-05T19:49:33Z
# 2     anaxai    349  2020-03-05T19:49:33Z
# 3     ajeen_    318  2020-03-05T19:49:33Z
# 4    norkore    302  2020-03-05T19:49:33Z
# 5     ludias    273  2020-03-05T19:49:33Z
# 6     fenrii    248  2020-03-05T19:49:33Z
# 7  yuyuyuna_    248  2020-03-05T19:49:33Z
# 8  kirisaite    233  2020-03-05T19:49:33Z
# 9    szary94    219  2020-03-05T19:49:33Z
# 2020-03-03T19:03:14Z
# SELECT username, COUNT(*) AS "count" from sodapoppin WHERE started_at = '2020-03-03T19:03:14Z' group by username ORDER BY COUNT DESC;
# <class 'pandas.core.frame.DataFrame'>
#         word  count            started_at
# 0       LULW   5788  2020-03-03T19:03:14Z
# 1        Pog   3455  2020-03-03T19:03:14Z
# 2     monkaW   3181  2020-03-03T19:03:14Z
# 3   OMEGALUL   3126  2020-03-03T19:03:14Z
# 4        the   3081  2020-03-03T19:03:14Z
# 5  PepeLaugh   2479  2020-03-03T19:03:14Z
# 6         is   2351  2020-03-03T19:03:14Z
# 7        you   2330  2020-03-03T19:03:14Z
# 8        LUL   1980  2020-03-03T19:03:14Z
# 9          a   1890  2020-03-03T19:03:14Z
# <class 'pandas.core.frame.DataFrame'>
#        username  count            started_at
# 0     kirisaite    676  2020-03-03T19:03:14Z
# 1        ludias    522  2020-03-03T19:03:14Z
# 2        anaxai    519  2020-03-03T19:03:14Z
# 3     guactoast    480  2020-03-03T19:03:14Z
# 4  basictuesday    480  2020-03-03T19:03:14Z
# 5     victorjsz    420  2020-03-03T19:03:14Z
# 6       sador90    369  2020-03-03T19:03:14Z
# 7      vissione    360  2020-03-03T19:03:14Z
# 8          zuby    277  2020-03-03T19:03:14Z
# 9   smellygoatz    255  2020-03-03T19:03:14Z

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.graph_objects as go

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.express as px
import plotly.graph_objects as go
import plotly

# %%
def draw_top(df_top, template_number, dir, title, col):
        template = f"chart{template_number}.png"
        chart = px.bar(df_top, x=df_top.keys()[0],y=df_top.keys()[1], color=df_top.iloc[:, col])
        chart.update_layout(showlegend=False)
        chart.update_traces( 
            marker_line_color='rgb(8,48,107)',
            marker_line_width=1.5, opacity=0.6
        )
        chart.update_layout(title_text=title)
        chart.write_image(template)
        return template

# %%
worker = Worker("sodapoppin")

for j in worker.get_subset().values: 
    print(j[0])
    data_frame = worker._get_data_frame(j[0])

    top_words = data_frame.top_words_usage('msg', 10)
    worker._set_top_attr('Words', top_words)
    top_users = worker.stream_t.top_users_sql()[:25]
    worker._set_top_attr('Users', top_users)
#     draw_top(top_users, j[0] + "u", "sodapoppin", "Top10 humans in the chat", 0)
#     draw_top(top_words, j[0] + "w", "sodapoppin", "Top10 words in the chat", 1)
    worker.top_t.write_df_to_sql({'started_at': j[0]})
# Out:
# 2020-03-04T19:52:16Z
# SELECT username, COUNT(*) AS "count" from sodapoppin WHERE started_at = '2020-03-04T19:52:16Z' group by username ORDER BY COUNT DESC;
# <class 'pandas.core.frame.DataFrame'>
# 18          zuby    151  2020-03-05T19:49:33Z
# 19         eirwe    146  2020-03-05T19:49:33Z
# 20      vulpeshd    145  2020-03-05T19:49:33Z
# 21      swaggy_i    142  2020-03-05T19:49:33Z
# 22      aquagasm    140  2020-03-05T19:49:33Z
# 23      ledzeeej    138  2020-03-05T19:49:33Z
# 24     delta3388    133  2020-03-05T19:49:33Z
# 2020-03-03T19:03:14Z
# SELECT username, COUNT(*) AS "count" from sodapoppin WHERE started_at = '2020-03-03T19:03:14Z' group by username ORDER BY COUNT DESC;
# <class 'pandas.core.frame.DataFrame'>
#         word  count            started_at
# 0       LULW   5788  2020-03-03T19:03:14Z
# 1        Pog   3455  2020-03-03T19:03:14Z
# 2     monkaW   3181  2020-03-03T19:03:14Z
# 3   OMEGALUL   3126  2020-03-03T19:03:14Z
# 4        the   3081  2020-03-03T19:03:14Z
# 5  PepeLaugh   2479  2020-03-03T19:03:14Z
# 6         is   2351  2020-03-03T19:03:14Z
# 7        you   2330  2020-03-03T19:03:14Z
# 8        LUL   1980  2020-03-03T19:03:14Z
# 9          a   1890  2020-03-03T19:03:14Z
# <class 'pandas.core.frame.DataFrame'>
#                 username  count            started_at
# 0              kirisaite    676  2020-03-03T19:03:14Z
# 1                 ludias    522  2020-03-03T19:03:14Z
# 2                 anaxai    519  2020-03-03T19:03:14Z
# 3              guactoast    480  2020-03-03T19:03:14Z
# 4           basictuesday    480  2020-03-03T19:03:14Z
# 5              victorjsz    420  2020-03-03T19:03:14Z
# 6                sador90    369  2020-03-03T19:03:14Z
# 7               vissione    360  2020-03-03T19:03:14Z
# 8                   zuby    277  2020-03-03T19:03:14Z
# 9            smellygoatz    255  2020-03-03T19:03:14Z
# 10            dimortilus    244  2020-03-03T19:03:14Z
# 11              jazzykat    239  2020-03-03T19:03:14Z
# 12              joweni38    225  2020-03-03T19:03:14Z
# 13                sugino    224  2020-03-03T19:03:14Z
# 14               mr_ragr    218  2020-03-03T19:03:14Z
# 15             sadpandah    217  2020-03-03T19:03:14Z
# 16             whos_nick    217  2020-03-03T19:03:14Z
# 17           sharkcity77    214  2020-03-03T19:03:14Z
# 18  mau5mau5mau5mau5mau5    196  2020-03-03T19:03:14Z
# 19               5idi233    194  2020-03-03T19:03:14Z
# 20           lemurbreath    177  2020-03-03T19:03:14Z
# 21               sirkwak    177  2020-03-03T19:03:14Z
# 22       unbrokenlol1111    171  2020-03-03T19:03:14Z
# 23            crossfirev    171  2020-03-03T19:03:14Z
# 24                bhaaku    168  2020-03-03T19:03:14Z

# %%
def draw_chart_by_time(df, title):
    data = []
    for key, item in df.groupby(df.keys()[1]):
        if item['started_at'].count() > 4:
            data.append(go.Scatter(
                x=item['started_at'],
                y=item['count'],   
                name=key,     
                marker={'size':3},
                marker_line_width=1
            ))
    layout = {'title': title}
    fig = go.Figure(data=data, layout=layout)
    fig.update_layout(legend_orientation="h")
    fig.write_image(f"./chart{title}.png")

# %%
top_tab = TopTable('sodapoppin')

for k, v in top_tab.read_tops().items():
    print(1)
    draw_chart_by_time(v, k)
# Out:
# 1
# 1

# %%
# Out:
# 6
